# %% [markdown]
# # ANÁLISIS DESCRIPTIVO DE LA BASE DE DATOS ECOMMERCE DE RSM

# %%
import pandas as pd
df = pd.read_excel('BasedeDatosEcommerce.xlsx')
df.head()
# Out:
#    VentaID  ClienteID Clientes.NombreCliente         Clientes.Email  \
# 0      101       1058             Cliente 58  cliente58@example.com
# 1      174       1001              Cliente 1   cliente1@example.com
# 2      181       1005              Cliente 5   cliente5@example.com
# 3      139       1007              Cliente 7   cliente7@example.com
# 4      154       1001              Cliente 1   cliente1@example.com
#
#   Clientes.Telefono Clientes.Direccion  ProductoID Productos.NombreProducto  \
# 0          555-6730      Calle 58 #827         514              Producto 14
# 1          555-6805       Calle 1 #337         514              Producto 14
# 2          555-2684       Calle 5 #824         501               Producto 1
# 3          555-5890       Calle 7 #848         501               Producto 1
# 4          555-6805       Calle 1 #337         512              Producto 12
#
#   Productos.Categoria  Productos.PrecioUnitario  Cantidad FechaVenta Region  \
# ...

# %%
# Mostrar información del DataFrame
df.info()

# Mostrar estadísticas descriptivas
df.describe()

# Acceder a una columna específica
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   VentaID                   1000 non-null   int64
#  1   ClienteID                 1000 non-null   int64
#  2   Clientes.NombreCliente    1000 non-null   object
#  3   Clientes.Email            1000 non-null   object
#  4   Clientes.Telefono         1000 non-null   object
#  5   Clientes.Direccion        1000 non-null   object
#  6   ProductoID                1000 non-null   int64
#  7   Productos.NombreProducto  1000 non-null   object
#  8   Productos.Categoria       1000 non-null   object
#  9   Productos.PrecioUnitario  1000 non-null   float64
#  10  Cantidad                  1000 non-null   int64
#  11  FechaVenta                1000 non-null   datetime64[ns]
#  12  Region                    1000 non-null   object
# ...
